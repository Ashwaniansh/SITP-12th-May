# %%
import os

# %%
import os
os.getcwd()
# Out:
# 'd:\\Data Science with AI & ML\\OS'

# %%
path = r'd:\\Data Science with AI & ML\\OS'
os.listdir('d:\\Data Science with AI & ML\\OS')
# Out:
# ['Basic.ipynb']
