# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Data Science with AI & ML\SITP-12th-May\PANDAS\sales.csv")

# %%
df.head()
# Out:
#                               region                country        item_type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   sales_channel order_priority  order_date   order_id   ship_date  units_sold  \
# 0       Offline              H  2010-05-28  669165933  2010-06-27        9925
# 1        Online              C  2012-08-22  963881480  2012-09-15        2804
# 2       Offline              L  2014-05-02  341417157  2014-05-08        1779
# 3        Online              C  2014-06-20  514321792  2014-07-05        8102
# 4       Offline              L  2013-02-01  115456712  2013-02-06        5062
#
# ...

# %%
df.head(10)
# Out:
#                               region                country        item_type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   sales_channel order_priority  order_date   order_id   ship_date  units_sold  \
# ...

# %%
df.tail(10)
# Out:
#                                region       country        item_type  \
# 90                 Sub-Saharan Africa  Sierra Leone  Office Supplies
# 91              Australia and Oceania     Australia        Beverages
# 92       Middle East and North Africa    Azerbaijan  Office Supplies
# 93                             Europe       Romania        Cosmetics
# 94  Central America and the Caribbean     Nicaragua        Beverages
# 95                 Sub-Saharan Africa          Mali          Clothes
# 96                               Asia      Malaysia           Fruits
# 97                 Sub-Saharan Africa  Sierra Leone       Vegetables
# 98                      North America        Mexico    Personal Care
# 99                 Sub-Saharan Africa    Mozambique        Household
#
#    sales_channel order_priority  order_date   order_id   ship_date  \
# 90       Offline              H  2016-12-06  621386563  2016-12-14
# 91       Offline              H  2014-07-07  240470397  2014-07-11
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          100 non-null    str
#  1   country         100 non-null    str
#  2   item_type       100 non-null    str
#  3   sales_channel   100 non-null    str
#  4   order_priority  100 non-null    str
#  5   order_date      100 non-null    str
#  6   order_id        100 non-null    int64
#  7   ship_date       100 non-null    str
#  8   units_sold      100 non-null    int64
#  9   unit_price      100 non-null    float64
#  10  unit_cost       100 non-null    float64
#  11  total_revenue   100 non-null    float64
#  12  total_cost      100 non-null    float64
#  13  total_profit    100 non-null    float64
# dtypes: float64(5), int64(2), str(7)
# memory usage: 11.1 KB

# %%
df.shape
# Out:
# (100, 14)

# %%
df.columns
# Out:
# Index(['region', 'country', 'item_type', 'sales_channel', 'order_priority',
#        'order_date', 'order_id', 'ship_date', 'units_sold', 'unit_price',
#        'unit_cost', 'total_revenue', 'total_cost', 'total_profit'],
#       dtype='str')

# %%
df.columns = [c.strip().lower().replace(' ','_') for c in df.columns]
df.columns
# Out:
# Index(['region', 'country', 'item_type', 'sales_channel', 'order_priority',
#        'order_date', 'order_id', 'ship_date', 'units_sold', 'unit_price',
#        'unit_cost', 'total_revenue', 'total_cost', 'total_profit'],
#       dtype='str')

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
df.isnull().sum()
# Out:
# region            0
# country           0
# item_type         0
# sales_channel     0
# order_priority    0
# order_date        0
# order_id          0
# ship_date         0
# units_sold        0
# unit_price        0
# unit_cost         0
# total_revenue     0
# total_cost        0
# total_profit      0
# dtype: int64

# %%
print('Duplicates:', df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# Duplicates: 0

# %%
df.describe(include='all')
# Out:
#                     region     country item_type sales_channel order_priority  \
# count                  100         100       100           100            100
# unique                   7          76        12             2              4
# top     Sub-Saharan Africa  The Gambia   Clothes       Offline              H
# freq                    36           4        13            50             30
# mean                   NaN         NaN       NaN           NaN            NaN
# min                    NaN         NaN       NaN           NaN            NaN
# 25%                    NaN         NaN       NaN           NaN            NaN
# 50%                    NaN         NaN       NaN           NaN            NaN
# 75%                    NaN         NaN       NaN           NaN            NaN
# max                    NaN         NaN       NaN           NaN            NaN
# std                    NaN         NaN       NaN           NaN            NaN
#
# ...

# %%
numeric_df = df.select_dtypes(include=np.number)
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
profit_region = df.groupby('region')['total_profit'].sum().sort_values(ascending=False)
plt.figure(figsize=(12,6))
sns.barplot(x=profit_region.index, y=profit_region.values)
plt.xticks(rotation=45)
plt.title('Total Profit by Region')
plt.show()

# %%
top_country = df.groupby('country')['total_revenue'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=top_country.values, y=top_country.index)
plt.title('Top 10 Countries by Revenue')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, y='item_type', order=df['item_type'].value_counts().index)
plt.title('Item Type Distribution')
plt.show()

# %%
sns.histplot(df['units_sold'], kde=True)
plt.title('Distribution of Units Sold')
plt.show()

# %%
sns.scatterplot(data=df, x='total_revenue', y='total_profit', hue='sales_channel')
plt.title('Revenue vs Profit')
plt.show()

# %%
sns.boxplot(data=df, x='sales_channel', y='total_profit')
plt.title('Profit by Sales Channel')
plt.show()

# %%
monthly = df.groupby(df['order_date'].dt.to_period('M'))['total_revenue'].sum()
monthly.index = monthly.index.astype(str)
plt.figure(figsize=(14,5))
sns.lineplot(x=monthly.index, y=monthly.values, marker='o')
plt.xticks(rotation=90)
plt.title('Monthly Revenue Trend')
plt.show()

# %%
sns.countplot(data=df, x='order_priority')
plt.title('Order Priority Distribution')
plt.show()

# %%
# df.to_csv(r"D:\Data Science with AI & ML\SITP-12th-May\PANDAS\sales.csv", index=False)
# print('Saved Successfully')

# %%
df.to_csv('Sales_clean_data.csv')
