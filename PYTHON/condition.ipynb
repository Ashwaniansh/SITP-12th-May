# %%
amount = int(input("Enter order amount: "))
if amount >= 200:
    print("Free Delivery Available")
else:
    print("Delivery Charges Applied")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 amount = int(input("Enter order amount: "))
#       2
#       3 if amount >= 200:
#       4     print("Free Delivery Available")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
signal="red"
if signal == "red":
  print("Stop")
# Out:
# Stop

# %%
color = input("Enter traffic light color: ")
if color == "red":
    print("STOP")
    
elif color == "yellow":
    print("READY")
    
elif color == "green":
    print("GO")
    
else:
    print("Invalid Color")

# %%
# student fail & pass
max = 30
if max <=33:
  print("Fail")
else:
  print("Pass")

# %%
bal = 5000
withdraw = 2000
if withdraw <=bal:
  print("Aapke account me rupaya hai")
else:
  print("Bhaiya itne rupaya nahi hai")

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")

# %%
num = input("Enter your Number")
print(type(num))

# %%
#Nested condition
attendence = 80
marks = 35
if attendence >= 75:
  if marks >=36:
    print("Pass")
  else:
    print("Fail in exam")
else:
  print("Low Attendence")
# Out:
# Fail in exam

# %%
password = input("Enter password: ")
if len(password) >= 12:
    if password == "Ashwani@76887.":
        print("Login Successful")
    else:
        print("Wrong Password")
else:
    print("Password must contain at least 12 characters")
