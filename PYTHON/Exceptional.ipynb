# %% [markdown]
# Exception Handling in Python
#
# Definition:
# Exception handling is used to handle errors that occur during program execution, preventing the program from crashing.
#
# Syntax
# try:
#     # Code that may cause an error
# except:
#     # Code to handle the error
# Example 1: Handling Division by Zero
# try:
#     a = 10
#     b = 0
#     print(a / b)
# except ZeroDivisionError:
#     print("Cannot divide by zero")
#
# Output:
#
# Cannot divide by zero
# Example 2: Handling Multiple Exceptions
# try:
#     num = int(input("Enter a number: "))
#     result = 10 / num
#     print(result)
#
# except ValueError:
#     print("Please enter a valid number")
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")
# else Block
#
# Runs when no exception occurs.
#
# try:
#     num = int(input("Enter a number: "))
#     print(10 / num)
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")
#
# else:
#     print("Program executed successfully")
# finally Block
#
# Runs whether an exception occurs or not.
#
# try:
#     num = int(input("Enter a number: "))
#     print(10 / num)
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")
#
# finally:
#     print("This block always executes")
# Exception Handling Structure
# try:
#     # risky code
# except ExceptionType:
#     # handle error
# else:
#     # execute if no error
# finally:
#     # always execute
# Common Exceptions
# Exception	Description
# ZeroDivisionError	Division by zero
# ValueError	Invalid value
# TypeError	Wrong data type
# IndexError	Invalid list index
# KeyError	Dictionary key not found
# FileNotFoundError	File does not exist
#
# In simple words: Exception handling helps a program continue running smoothly even when errors occur.
#
# python exception
# Python Exceptions
# What is an Exception?
#
# An exception is an error that occurs during the execution of a program. When an exception occurs, Python stops the normal flow of the program and displays an error message.
#
# Common Python Exceptions
# Exception	Description
# ZeroDivisionError	Division by zero
# ValueError	Invalid value entered
# TypeError	Operation on incompatible data types
# IndexError	List index out of range
# KeyError	Dictionary key not found
# NameError	Variable not defined
# FileNotFoundError	File does not exist
# Example 1: ZeroDivisionError
# a = 10
# b = 0
# print(a / b)
#
# Output:
#
# ZeroDivisionError: division by zero
# Example 2: ValueError
# num = int("Hello")
# print(num)
#
# Output:
#
# ValueError: invalid literal for int()
# Handling Exceptions
# try:
#     a = 10
#     b = 0
#     print(a / b)
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")
#
# Output:
#
# Cannot divide by zero
# Example with Multiple Exceptions
# try:
#     num = int(input("Enter a number: "))
#     result = 10 / num
#     print(result)
#
# except ValueError:
#     print("Invalid input")
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")
# Important Keywords
# try → Code that may cause an error.
# except → Handles the error.
# else → Runs if no error occurs.
# finally → Runs whether an error occurs or not.
# Syntax
# try:
#     # risky code
# except:
#     # handle exception
# else:
#     # execute if no exception
# finally:
#     # always execute
#
# Definition (Exam Point of View):
# Python exception is an event that occurs during program execution and interrupts the normal flow of the program. Exception handling is used to handle such errors and prevent program termination.

# %% [markdown]
# | Exception             | Description                            |
# | --------------------- | -------------------------------------- |
# | `ZeroDivisionError`   | Number ko 0 se divide karna            |
# | `ValueError`          | Wrong value type dena                  |
# | `TypeError`           | Different incompatible types use karna |
# | `NameError`           | Undefined variable use karna           |
# | `IndexError`          | Invalid list index access karna        |
# | `KeyError`            | Dictionary me missing key access karna |
# | `FileNotFoundError`   | File exist na karna                    |
# | `AttributeError`      | Invalid attribute/method access karna  |
# | `ImportError`         | Module import na hona                  |
# | `ModuleNotFoundError` | Module install na hona                 |

# %%
# try:
#   pass
# except:
#   pass
# else:
#   pass
# finally:
#   pass

# %%
try:
  a=10
  b=0
  print(a/b)

except ZeroDivisionError as e:
  print(e)
# Out:
# division by zero

# %%
try:
   name = "Ashwani"
   number = 2
   print(name+number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 name = "Ashwani"
#       2 number = 2
# ----> 3 name+number
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
  a=int(input("Enter first number:-"))
  b=int(input("Enter second number:-"))
  print(a/b)
except ZeroDivisionError as e:
  print(e)
except ValueError as e:
  print(e)
# Out:
# invalid literal for int() with base 10: ''

# %%
try:
  print(lastname)
except NameError as e:
  print(e)
# Out:
# name 'lastname' is not defined

# %%
try:
  lst = [10,1,2,3,4,5,6,7,8,9]
  lst[12]
except IndexError as e:
  print(e)
# Out:
# list index out of range

# %%
try:
  file = open("demo.txt","r")
except FileNotFoundError as e:
  print("File not found",e)
# Out:
# File not found [Errno 2] No such file or directory: 'demo.txt'

# %%
try:
   num=int(input("Enter number:-"))
except ValueError as e:
   print("Invalid Input",e)
else:
   print("Your Input",num)
finally:
   print("I am always ready.")

# %%
age =-5
if age <0:
  raise Exception("Age cannot be negative.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 age =-5
#       2 if age <0:
# ----> 3   raise Exception("Age cannot be negative.")
#
# Exception: Age cannot be negative.

# %%
name =""
if name =="":
  raise Exception("Name cannot be empty.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 name =""
#       2 if name =="":
# ----> 3   raise Exception("Name cannot be empty.")
#
# Exception: Name cannot be empty.

# %%
try:
  age =-5
  if age<0:
     raise Exception("Age can't be negative.")
except ValueError as e:
   print(e)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 try:
#       2   age =-5
#       3   if age<0:
#       4      raise Exception("Age can't be negative.")
# ----> 5 except ValueError as e:
#       6    print(e)
#
# Exception: Age can't be negative.

# %%
class InvalidedgeError(Exception):
  pass
age = 15
if age <18:
  raise InvalidedgeError("You are not eligble to vote.")
# Out:
# ---------------------------------------------------------------------------
# InvalidedgeError                          Traceback (most recent call last)
# Cell In[1], line 5
#       1 class InvalidedgeError(Exception):
#       2   pass
#       3 age = 15
#       4 if age <18:
# ----> 5   raise InvalidedgeError("You are not eligble to vote.")
#
# InvalidedgeError: You are not eligble to vote.

# %%
class InvalidedgeError(Exception):
  pass
try:
  age = 17
  if age <18:
     raise InvalidedgeError("You are not eligble to vote.")
  print("You can vote.")
except InvalidedgeError as e:
  print(e)
# Out:
# You are not eligble to vote.

# %%
class ATM:
    def __init__(self, balance):
        self.balance = balance
    def withdraw(self, amount):
        if amount>self.balance:
            raise Exception("Balance uplabdh nahi hai")
        else:
            self.balance -= amount
            print("Rupaya successfull hua.")
            print("Bacha hua rupaya(Balance):", self.balance)
atm = ATM(5000)
try:
    atm.withdraw(7000)
except Exception as e:
    print("Error:", e)
# Out:
# Error: Balance uplabdh nahi hai

# %%
class Class_name(Exception):
  pass
try:
  bal = 5000
  val = 4000
  if val>bal:
    raise Class_name("Bhai tere account me itna rupaya nahi hai")
  print("Rupaya nahi hai.")
except Class_name as e:
  print(e)
# Out:
# Rupaya nahi hai.
