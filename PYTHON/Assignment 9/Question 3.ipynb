# %%
class Book:
  def __init__(self, title, author, price):
    self.title = title
    self.author = author
    self.price = price
  def display(self):
    print("Title:", self.title)
    print("Author:", self.author)
    print("Price:", self.price)
    print(">>>>>>>>>><<<<<<<<<<")
b1 = Book("Python Basics", "John Macarthy", 589)
b1.display()
# Out:
# Title: Python Basics
# Author: John Macarthy
# Price: 589
# >>>>>>>>>><<<<<<<<<<
