# %%
class Vehicle:
    def display(self):
        print("This is a vehicle")
class Car(Vehicle):
    def show(self):
        super().display()
        print("This is a car")
c1 = Car()
c1.show()
# Out:
# This is a vehicle
# This is a car
